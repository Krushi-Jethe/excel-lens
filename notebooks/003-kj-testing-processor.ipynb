# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from excel_lens import ExcelDataExtractor

extractor = ExcelDataExtractor()
output = extractor.extract("../../GotheBluesV1.0.xlsx")
# Out:
# /home/kj1909/anaconda3/envs/excel-lens/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# /home/kj1909/anaconda3/envs/excel-lens/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# /home/kj1909/anaconda3/envs/excel-lens/lib/python3.12/site-packages/openpyxl/reader/drawings.py:33: UserWarning: DrawingML support is incomplete and limited to charts and images only. Shapes and drawings will be lost.
#   warn("DrawingML support is incomplete and limited to charts and images only. Shapes and drawings will be lost.")

# %%
output.sheets
# Out:
# []

# %%
import pandas as pd
all_sheets = pd.read_excel("../../GotheBluesV1.0.xlsx", sheet_name=None)
# Out:
# /home/kj1909/anaconda3/envs/excel-lens/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)

# %%
extractor.extract_tables_sep_by_rows(all_sheets["Calcs"]).keys()
# Out:
# dict_keys(['table_1', 'table_2', 'table_3', 'table_4', 'table_5', 'table_6', 'table_7', 'table_8', 'table_9', 'table_10', 'table_11'])

# %%
row_tables = extractor.extract_tables_sep_by_rows(all_sheets["Calcs"])
row_tables.keys()
# Out:
# dict_keys(['table_1', 'table_2', 'table_3', 'table_4', 'table_5', 'table_6', 'table_7', 'table_8', 'table_9', 'table_10', 'table_11'])

# %%
row_tables = {table_name: extractor.remove_nan_cols(table) for table_name, table in row_tables.items()}
row_tables = {table_name: extractor.remove_nan_rows(table) for table_name, table in row_tables.items()}

# %%
row_tables.keys()
# Out:
# dict_keys(['table_1', 'table_2', 'table_3', 'table_4', 'table_5', 'table_6', 'table_7', 'table_8', 'table_9', 'table_10', 'table_11'])

# %%
row_tables['table_1']
# Out:
#    Region                 Date P&L Actual   P&L Budget Rev Actual   \
# 0   Wales  2019-01-01 00:00:00    2169.75  1791.110722    3057.375
# 1   Wales  2019-02-01 00:00:00       2310  1856.957538        3255
# 2   Wales  2019-03-01 00:00:00       1991  1845.404618      2805.5
# 3   Wales  2019-04-01 00:00:00     1842.5   1652.71215     2596.25
# 4   Wales  2019-05-01 00:00:00     345.25    443.57867    1057.375
# 5   Wales  2019-06-01 00:00:00      233.5     53.97319        1255
# 6   Wales  2019-07-01 00:00:00   2195.625  2033.975213        3000
# 7   Wales  2019-08-01 00:00:00     1765.5  1443.743724        2760
# 8   Wales  2019-09-01 00:00:00    3037.65  2507.555011    4280.325
# 9   Wales  2019-10-01 00:00:00       3234  2599.740554        4557
# 10  Wales  2019-11-01 00:00:00     2787.4  2583.566465      3927.7
# 11  Wales  2019-12-01 00:00:00     2579.5   2313.79701     3634.75
# 12  Wales  2020-01-01 00:00:00    1883.35  1393.302638    2880.325
# ...

# %%
row_tables['table_2']
# Out:
#    Region P&L Actual    P&L Budget Rev Actual  Rev Budget Exp Actual  \
# 0  Totals  57865.565  49281.871711    84010.52  75722.193  26144.955
#
#      Exp Budget P&L Actual.1  P&L Budget.1
# 0  26440.321289    57865.565  49281.871711
